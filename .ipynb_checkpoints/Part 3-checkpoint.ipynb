# %% [markdown]
# # Projeto Prático 2 - Parte III
#
# #### Alunos:
#    - Bonifácio de Oliveira (bldof.eng16@uea.edu.br)
#    - Luiz Fábio (lfba.lic17@uea.edu.br)
#    - Luiz Felipe (lfda.lic17@uea.edu.br)
#    - Rafaela Melo (rmf.lic16@uea.edu.br)

# %%
import numpy as np
import pandas as pd
import random
from random import  uniform
import statistics
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sn

# %% [markdown]
# # Classe do neurônio de Rosenblatt

# %%
class Neuronio:
    
    def __init__(self):
        self.dados = np.array([])
        self.x_treino = np.array([])
        self.x_teste = np.array([])
        
        self.carrega_dados()
        
        self.pesos = np.array([
            uniform(-.5, .5),
            uniform(-.5, .5),
            uniform(-.5, .5)
        ])
        
        self.teta = 0
        self.ta   = 0.1
        self.vies = -1
        self.total_de_ajustes = []
        self.epocas = 0
        self.x1 = 0
        self.x2 = 0
        
    def carrega_dados_treino_e_teste(self):
        random.shuffle(self.dados)

        distribuicao = int(len(self.dados)*0.7)

        self.x_treino = self.dados[:distribuicao]
        self.x_teste  = self.dados[distribuicao:]
    
    def carrega_dados(self):
        dataset = np.fromfile('dataHoldout.txt')
        linhas  = len(dataset)//3
        colunas = 3
        self.dados = dataset.reshape(linhas, colunas)
        
        self.carrega_dados_treino_e_teste()
    
    def mostra_grafico(self):
        fig, ax = plt.subplots()
        for i in self.dados:
            x = i[0]
            y = i[1]
            yd = int(i[2])
            if(yd >= 1):
                plt.scatter(x,y, color='r', s=8)
            else:
                plt.scatter(x,y, color='b', s=8)

        ponto1 = [0,self.x1]
        ponto2 = [self.x2,0]
        x_values = [ponto1[0], ponto2[0]]
        y_values = [ponto1[1], ponto2[1]]

        ax.plot(x_values, y_values)
        plt.show()
        
    def funcao_ativacao(self,num):
        if (num>=self.teta):
            return 1
        else:
            return 0
        
    def perceptron(self):
        numero_de_ajustes = 0
        
        #Embaralha os dados
        self.dados = list(self.dados)
        random.shuffle(self.dados)
        self.dados = np.array(self.dados)
        
        print("Conjunto de dados embaralhado: \n",self.dados,"\n")
        
        for i in self.dados:
            
            entrada = np.concatenate((np.array([self.vies]), i[:2]))
            yd = int(i[2:])
            yr = round(entrada.dot(self.pesos),4)
            yr = self.funcao_ativacao(yr)
            
            numero_de_ajustes += 1
            #print("Dado: ",entrada[1:],"\n")
            self.pesos = self.ajuste_de_peso(yd, yr, entrada)
            
            if(yr != yd):
                self.total_de_ajustes.append(numero_de_ajustes)
                return False
            
        self.total_de_ajustes.append(numero_de_ajustes)
        return True

    def ajuste_de_peso(self, yd, yr, entrada):
        delta = self.ta * np.array(yd - yr).dot(entrada)
        novos_pesos = self.pesos + delta
        
        return novos_pesos
    
    def descobre_x1_x2(self):
        w = self.pesos
        
        w0_w2 = w[0]/w[2]
        w1_w2 = w[1]/w[2]

        self.x2 = w0_w2 - w1_w2 * 0
        self.x1 = w0_w2/w1_w2
    
    def treino(self):
        self.epocas = 1
        print("-----------------------------\nÉpoca: ",self.epocas,"\n")
        #100 epocas
        while(self.epocas<100):
            if(self.perceptron() == False):
                self.epocas += 1
                print("-----------------------------\nÉpoca: ",self.epocas,"\n")
            else:
                break
            
        self.descobre_x1_x2()

        print("Total de épocas: ",self.epocas)
        print("Total de ajustes feitos nos pesos: ",sum(self.total_de_ajustes))
        
n = Neuronio()

# %%
n.mostra_grafico()

# %%
n.dados = n.x_treino
n.treino()
# Out:
# -----------------------------
# Época:  1
#
# Conjunto de dados embaralhado:
#  [[ 0.03195638 -0.10251385  1.        ]
#  [-0.00967382  0.89776318  0.        ]
#  [-0.04716837  0.19363929  1.        ]
#  ...
#  [ 0.01272533  0.20346543  1.        ]
#  [-0.22671361  0.21841371  1.        ]
#  [-0.07825563 -0.08083512  1.        ]]
#
# -----------------------------
# Época:  2
#
# Conjunto de dados embaralhado:
#  [[ 0.20013586 -0.41657686  1.        ]
#  [ 0.32622018 -0.00707064  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  ...
#  [ 0.26985956  0.87102575  0.        ]
#  [ 0.29230086  1.36100048  0.        ]
#  [ 1.10933458 -0.18927038  0.        ]]
#
# -----------------------------
# Época:  3
#
# Conjunto de dados embaralhado:
#  [[-0.32030378 -0.05453506  1.        ]
#  [ 0.01327531  1.10693866  0.        ]
#  [-0.3001711   0.32724374  1.        ]
#  ...
#  [-0.0054924  -0.30231266  1.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  [-0.28620777  1.059365    0.        ]]
#
# -----------------------------
# Época:  4
#
# Conjunto de dados embaralhado:
#  [[ 0.23012362 -0.26821715  1.        ]
#  [-0.05213949 -0.05768201  1.        ]
#  [ 0.46304142  0.09405471  1.        ]
#  ...
#  [ 0.03416729  0.17169338  1.        ]
#  [-0.18164836  0.0789158   1.        ]
#  [ 1.02481706 -0.32122131  0.        ]]
#
# -----------------------------
# Época:  5
#
# Conjunto de dados embaralhado:
#  [[ 0.28066172  0.13031361  1.        ]
#  [-0.13901236  1.07240867  0.        ]
#  [-0.03486406  1.15509737  0.        ]
#  ...
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [-0.01249701  1.13463856  0.        ]]
#
# -----------------------------
# Época:  6
#
# Conjunto de dados embaralhado:
#  [[ 0.08298076  0.12868493  1.        ]
#  [ 0.14814828  1.19025708  0.        ]
#  [ 0.15338027  1.0060764   0.        ]
#  ...
#  [ 0.27835023 -0.27168854  1.        ]
#  [-0.27139883  0.26947543  0.        ]
#  [ 0.00359837  0.18216627  1.        ]]
#
# -----------------------------
# Época:  7
#
# Conjunto de dados embaralhado:
#  [[ 0.01047289 -0.025923    1.        ]
#  [ 0.19110701  0.2105866   1.        ]
#  [ 0.02313303  0.79371367  0.        ]
#  ...
#  [ 0.28382866 -0.00689202  1.        ]
#  [ 0.00976696 -0.02053641  1.        ]
#  [-0.20389569  0.36597829  1.        ]]
#
# -----------------------------
# Época:  8
#
# Conjunto de dados embaralhado:
#  [[-0.04197909  0.89107395  0.        ]
#  [ 0.59465295  0.20180593  0.        ]
#  [ 0.15640596  0.84981368  0.        ]
#  ...
#  [-0.2622912   1.07843455  0.        ]
#  [ 0.0114998  -0.05939114  1.        ]
#  [ 0.35371839  0.80858185  0.        ]]
#
# -----------------------------
# Época:  9
#
# Conjunto de dados embaralhado:
#  [[ 0.0114998  -0.05939114  1.        ]
#  [-0.62237404  0.12119507  1.        ]
#  [ 0.17537603  0.17826557  1.        ]
#  ...
#  [-0.26331619  1.10614004  0.        ]
#  [-0.29322959 -0.09065359  1.        ]
#  [-0.23436994  0.03978647  1.        ]]
#
# -----------------------------
# Época:  10
#
# Conjunto de dados embaralhado:
#  [[ 0.20300365  0.19595358  1.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [ 0.19031887  0.13251078  1.        ]
#  ...
#  [ 0.46304142  0.09405471  1.        ]
#  [-0.19649707 -0.11955184  1.        ]
#  [ 0.04253339  0.4469942   1.        ]]
#
# -----------------------------
# Época:  11
#
# Conjunto de dados embaralhado:
#  [[-0.02215321  0.00269713  1.        ]
#  [ 0.08179828 -0.09956027  1.        ]
#  [ 0.27835023 -0.27168854  1.        ]
#  ...
#  [ 0.07180622  0.49468375  1.        ]
#  [ 0.26394155  0.32750883  1.        ]
#  [ 0.06627455 -0.26057051  1.        ]]
#
# -----------------------------
# Época:  12
#
# Conjunto de dados embaralhado:
#  [[ 1.13637183 -0.09968278  0.        ]
#  [-0.18071949  0.99659993  0.        ]
#  [-0.28552876 -0.16910219  1.        ]
#  ...
#  [ 0.40713655  1.3881116   0.        ]
#  [-0.22671361  0.21841371  1.        ]
#  [ 0.36729907  0.07514918  1.        ]]
#
# -----------------------------
# Época:  13
#
# Conjunto de dados embaralhado:
#  [[-0.52664262 -0.03855007  1.        ]
#  [ 0.07180622  0.49468375  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  ...
#  [ 0.35371839  0.80858185  0.        ]
#  [ 0.32622018 -0.00707064  1.        ]
#  [-0.19087107  1.1429872   0.        ]]
#
# -----------------------------
# Época:  14
#
# Conjunto de dados embaralhado:
#  [[ 0.03016264  0.98661861  0.        ]
#  [ 0.15338027  1.0060764   0.        ]
#  [ 0.01327531  1.10693866  0.        ]
#  ...
#  [-0.19649707 -0.11955184  1.        ]
#  [-0.20389569  0.36597829  1.        ]
#  [ 0.12020386  0.40989806  1.        ]]
#
# -----------------------------
# Época:  15
#
# Conjunto de dados embaralhado:
#  [[-0.31310084  0.27736732  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.34226827  1.29302582  0.        ]
#  ...
#  [-0.28620777  1.059365    0.        ]
#  [ 0.06627455 -0.26057051  1.        ]
#  [-0.06832331  1.1562397   0.        ]]
#
# -----------------------------
# Época:  16
#
# Conjunto de dados embaralhado:
#  [[ 0.80502291 -0.12324873  0.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  [-0.03486406  1.15509737  0.        ]
#  ...
#  [ 0.14347628  0.25927685  1.        ]
#  [ 0.14927021  0.30009393  1.        ]
#  [ 0.15207387 -0.1526586   1.        ]]
#
# -----------------------------
# Época:  17
#
# Conjunto de dados embaralhado:
#  [[-0.02215321  0.00269713  1.        ]
#  [ 0.37222961  0.06930466  1.        ]
#  [ 0.19031887  0.13251078  1.        ]
#  ...
#  [ 0.12020386  0.40989806  1.        ]
#  [-0.29123621  0.11011622  1.        ]
#  [ 0.00866547  0.79757433  0.        ]]
#
# -----------------------------
# Época:  18
#
# Conjunto de dados embaralhado:
#  [[-0.2622912   1.07843455  0.        ]
#  [-0.26424484 -0.21427883  1.        ]
#  [ 0.22481021  1.51639247  0.        ]
#  ...
#  [-0.19649707 -0.11955184  1.        ]
#  [-0.21442938  0.00797897  1.        ]
#  [-0.33512655  1.1774808   0.        ]]
#
# -----------------------------
# Época:  19
#
# Conjunto de dados embaralhado:
#  [[ 0.08097161  0.30854443  1.        ]
#  [ 0.02409823  0.16569508  1.        ]
#  [-0.0180137   0.39719079  1.        ]
#  ...
#  [ 0.10233626  0.55422473  0.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [ 0.02015935  0.99317546  0.        ]]
#
# -----------------------------
# Época:  20
#
# Conjunto de dados embaralhado:
#  [[-0.19649707 -0.11955184  1.        ]
#  [ 0.21675147  0.54097717  1.        ]
#  [ 0.04253339  0.4469942   1.        ]
#  ...
#  [ 0.1639115   1.17985216  0.        ]
#  [-0.27139883  0.26947543  0.        ]
#  [ 0.01047289 -0.025923    1.        ]]
#
# -----------------------------
# Época:  21
#
# Conjunto de dados embaralhado:
#  [[-0.04162565  0.12822745  1.        ]
#  [-0.26329819  0.12863801  1.        ]
#  [ 0.48892004 -0.13726797  1.        ]
#  ...
#  [-0.06865786 -0.18994482  1.        ]
#  [ 0.32606995  0.33196305  1.        ]
#  [-0.19908835  0.12926358  1.        ]]
#
# -----------------------------
# Época:  22
#
# Conjunto de dados embaralhado:
#  [[ 0.11737716  0.99037835  0.        ]
#  [-0.01545201  0.94861297  0.        ]
#  [-0.3001711   0.32724374  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.02215321  0.00269713  1.        ]
#  [ 0.26985956  0.87102575  0.        ]]
#
# -----------------------------
# Época:  23
#
# Conjunto de dados embaralhado:
#  [[-0.00967382  0.89776318  0.        ]
#  [ 0.03195638 -0.10251385  1.        ]
#  [-0.20009509  0.37511566  1.        ]
#  ...
#  [ 0.12020386  0.40989806  1.        ]
#  [-0.29356844  0.00599321  1.        ]
#  [ 0.24890183  1.0739442   0.        ]]
#
# -----------------------------
# Época:  24
#
# Conjunto de dados embaralhado:
#  [[ 0.15447827  1.03054581  0.        ]
#  [-0.16562461  0.00357497  1.        ]
#  [-0.03883705  0.13043894  1.        ]
#  ...
#  [ 0.08948218 -0.22242627  1.        ]
#  [ 0.55418408 -0.40033314  0.        ]
#  [ 0.14139125  1.19105258  0.        ]]
#
# -----------------------------
# Época:  25
#
# Conjunto de dados embaralhado:
#  [[-0.13901236  1.07240867  0.        ]
#  [ 0.21675147  0.54097717  1.        ]
#  [ 0.19031887  0.13251078  1.        ]
#  ...
#  [-0.28552876 -0.16910219  1.        ]
#  [ 0.16775772  0.22831062  1.        ]
#  [ 0.19559446 -0.36660313  1.        ]]
#
# -----------------------------
# Época:  26
#
# Conjunto de dados embaralhado:
#  [[-0.01249701  1.13463856  0.        ]
#  [ 0.15371662  0.27078076  1.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  ...
#  [ 0.55358262  1.12372063  0.        ]
#  [ 0.24063399  0.68816436  0.        ]
#  [ 0.06627455 -0.26057051  1.        ]]
#
# -----------------------------
# Época:  27
#
# Conjunto de dados embaralhado:
#  [[-0.2622912   1.07843455  0.        ]
#  [-0.0294872   0.13216526  1.        ]
#  [ 0.00394505  0.1408983   1.        ]
#  ...
#  [ 0.24709879 -0.16289625  1.        ]
#  [ 1.13637183 -0.09968278  0.        ]
#  [ 1.18222635 -0.30020136  0.        ]]
#
# -----------------------------
# Época:  28
#
# Conjunto de dados embaralhado:
#  [[ 0.48892004 -0.13726797  1.        ]
#  [-0.21901569 -0.28125484  1.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  ...
#  [ 0.46304142  0.09405471  1.        ]
#  [ 0.08179828 -0.09956027  1.        ]
#  [-0.06865786 -0.18994482  1.        ]]
#
# -----------------------------
# Época:  29
#
# Conjunto de dados embaralhado:
#  [[ 0.28066172  0.13031361  1.        ]
#  [ 0.28382866 -0.00689202  1.        ]
#  [ 0.08097161  0.30854443  1.        ]
#  ...
#  [ 0.04253339  0.4469942   1.        ]
#  [-0.29912933  0.78267448  0.        ]
#  [ 0.14000195  1.0836725   0.        ]]
#
# -----------------------------
# Época:  30
#
# Conjunto de dados embaralhado:
#  [[ 0.14927021  0.30009393  1.        ]
#  [ 0.06627455 -0.26057051  1.        ]
#  [ 0.80502291 -0.12324873  0.        ]
#  ...
#  [-0.0294872   0.13216526  1.        ]
#  [ 0.07187886  1.06873787  0.        ]
#  [ 0.30399699  0.00645548  1.        ]]
#
# -----------------------------
# Época:  31
#
# Conjunto de dados embaralhado:
#  [[-0.03883705  0.13043894  1.        ]
#  [ 0.15252857  0.01744889  1.        ]
#  [-0.17369552 -0.02572443  1.        ]
#  ...
#  [ 0.08097161  0.30854443  1.        ]
#  [-0.33000132  0.07234854  1.        ]
#  [ 0.22481021  1.51639247  0.        ]]
#
# -----------------------------
# Época:  32
#
# Conjunto de dados embaralhado:
#  [[ 0.09389492  0.64342794  0.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [-0.21442938  0.00797897  1.        ]
#  ...
#  [ 0.2367801   0.37531654  1.        ]
#  [-0.02215321  0.00269713  1.        ]
#  [ 0.46304142  0.09405471  1.        ]]
#
# -----------------------------
# Época:  33
#
# Conjunto de dados embaralhado:
#  [[-0.32030378 -0.05453506  1.        ]
#  [ 0.04253339  0.4469942   1.        ]
#  [ 0.55418408 -0.40033314  0.        ]
#  ...
#  [-0.06835829 -0.22927445  1.        ]
#  [-0.03883705  0.13043894  1.        ]
#  [ 0.07936731 -0.18897409  1.        ]]
#
# -----------------------------
# Época:  34
#
# Conjunto de dados embaralhado:
#  [[-0.16653566  0.80353489  0.        ]
#  [ 0.40713655  1.3881116   0.        ]
#  [ 0.00359837  0.18216627  1.        ]
#  ...
#  [ 0.30399699  0.00645548  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  [-0.09127282  0.28768163  1.        ]]
#
# -----------------------------
# Época:  35
#
# Conjunto de dados embaralhado:
#  [[ 0.30399699  0.00645548  1.        ]
#  [ 0.20300365  0.19595358  1.        ]
#  [ 0.15338027  1.0060764   0.        ]
#  ...
#  [ 0.00531634 -0.05266985  1.        ]
#  [ 0.08298076  0.12868493  1.        ]
#  [-0.22615337  0.1493509   1.        ]]
#
# -----------------------------
# Época:  36
#
# Conjunto de dados embaralhado:
#  [[-1.39012360e-01  1.07240867e+00  0.00000000e+00]
#  [ 5.82495194e-02 -7.76054873e-02  1.00000000e+00]
#  [-1.24970115e-02  1.13463856e+00  0.00000000e+00]
#  ...
#  [-1.03915175e-01  3.46381919e-01  1.00000000e+00]
#  [ 8.24192013e-02  1.06606167e-03  1.00000000e+00]
#  [-1.06717243e-01 -4.45962833e-03  1.00000000e+00]]
#
# -----------------------------
# Época:  37
#
# Conjunto de dados embaralhado:
#  [[-0.22615337  0.1493509   1.        ]
#  [-0.21901569 -0.28125484  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [-0.01249701  1.13463856  0.        ]
#  [-0.62237404  0.12119507  1.        ]
#  [ 0.08562892 -0.17567279  1.        ]]
#
# -----------------------------
# Época:  38
#
# Conjunto de dados embaralhado:
#  [[ 0.14814828  1.19025708  0.        ]
#  [-0.00754979  0.90007524  0.        ]
#  [ 0.23012362 -0.26821715  1.        ]
#  ...
#  [-0.46833414 -0.10620722  1.        ]
#  [ 0.01004054 -0.29692638  1.        ]
#  [-0.0054924  -0.30231266  1.        ]]
#
# -----------------------------
# Época:  39
#
# Conjunto de dados embaralhado:
#  [[ 0.00866547  0.79757433  0.        ]
#  [ 0.26985956  0.87102575  0.        ]
#  [-0.03134909  1.34302578  0.        ]
#  ...
#  [-0.0150527  -0.12832773  1.        ]
#  [ 0.00531634 -0.05266985  1.        ]
#  [ 0.48892004 -0.13726797  1.        ]]
#
# -----------------------------
# Época:  40
#
# Conjunto de dados embaralhado:
#  [[ 0.1196882   0.08875686  1.        ]
#  [ 1.19127938 -0.30479213  0.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  ...
#  [-0.15506501  0.12410647  1.        ]
#  [-0.18071949  0.99659993  0.        ]
#  [-0.3001711   0.32724374  1.        ]]
#
# -----------------------------
# Época:  41
#
# Conjunto de dados embaralhado:
#  [[ 0.01272533  0.20346543  1.        ]
#  [ 0.23941219  1.16358317  0.        ]
#  [ 0.08298076  0.12868493  1.        ]
#  ...
#  [-0.26924602  0.32950513  1.        ]
#  [-0.11163154  0.00851976  1.        ]
#  [-0.26329819  0.12863801  1.        ]]
#
# -----------------------------
# Época:  42
#
# Conjunto de dados embaralhado:
#  [[-0.15506501  0.12410647  1.        ]
#  [ 0.1196882   0.08875686  1.        ]
#  [ 0.34038083  0.70804534  0.        ]
#  ...
#  [-0.18777062  0.42687831  1.        ]
#  [ 0.07180622  0.49468375  1.        ]
#  [ 0.15252857  0.01744889  1.        ]]
#
# -----------------------------
# Época:  43
#
# Conjunto de dados embaralhado:
#  [[-0.23593942  0.18670953  1.        ]
#  [ 0.20300365  0.19595358  1.        ]
#  [-0.31310084  0.27736732  1.        ]
#  ...
#  [ 0.00842475  0.20229318  1.        ]
#  [ 0.26394155  0.32750883  1.        ]
#  [-0.08482233  0.99780252  0.        ]]
#
# -----------------------------
# Época:  44
#
# Conjunto de dados embaralhado:
#  [[ 0.2367801   0.37531654  1.        ]
#  [-0.22671361  0.21841371  1.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  ...
#  [-0.24300515  0.15164356  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  [-0.10038537 -0.60750339  1.        ]]
#
# -----------------------------
# Época:  45
#
# Conjunto de dados embaralhado:
#  [[ 0.19559446 -0.36660313  1.        ]
#  [-0.33512655  1.1774808   0.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  ...
#  [ 0.11700025  0.64151874  0.        ]
#  [ 0.22635585  1.38432438  0.        ]
#  [ 0.1639115   1.17985216  0.        ]]
#
# -----------------------------
# Época:  46
#
# Conjunto de dados embaralhado:
#  [[ 0.00394505  0.1408983   1.        ]
#  [-0.07617946  0.02320954  1.        ]
#  [ 0.31474715 -0.09874167  1.        ]
#  ...
#  [ 0.00394505  0.1408983   1.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  [-0.3001711   0.32724374  1.        ]]
#
# -----------------------------
# Época:  47
#
# Conjunto de dados embaralhado:
#  [[ 0.02409823  0.16569508  1.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  [ 0.04253339  0.4469942   1.        ]
#  ...
#  [ 0.28066172  0.13031361  1.        ]
#  [-0.10391518  0.34638192  1.        ]
#  [ 0.00531634 -0.05266985  1.        ]]
#
# -----------------------------
# Época:  48
#
# Conjunto de dados embaralhado:
#  [[ 0.1889197   0.90694034  0.        ]
#  [ 1.27279874 -0.31974083  0.        ]
#  [-0.13901236  1.07240867  0.        ]
#  ...
#  [ 0.1889197   0.90694034  0.        ]
#  [-0.03134909  1.34302578  0.        ]
#  [ 0.05786483 -0.36451414  1.        ]]
#
# -----------------------------
# Época:  49
#
# Conjunto de dados embaralhado:
#  [[-0.0547258  -0.11131214  1.        ]
#  [-0.46833414 -0.10620722  1.        ]
#  [ 0.16775772  0.22831062  1.        ]
#  ...
#  [ 0.20300365  0.19595358  1.        ]
#  [ 0.19110701  0.2105866   1.        ]
#  [-0.23593942  0.18670953  1.        ]]
#
# -----------------------------
# Época:  50
#
# Conjunto de dados embaralhado:
#  [[ 1.42952247  0.15505646  0.        ]
#  [ 0.1196882   0.08875686  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  ...
#  [ 1.42952247  0.15505646  0.        ]
#  [-0.27139883  0.26947543  0.        ]
#  [ 0.04322791 -0.0461912   1.        ]]
#
# -----------------------------
# Época:  51
#
# Conjunto de dados embaralhado:
#  [[-0.22958441  1.05209844  0.        ]
#  [-0.09127282  0.28768163  1.        ]
#  [-0.00967382  0.89776318  0.        ]
#  ...
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.20300365  0.19595358  1.        ]
#  [-0.19217896  1.04049856  0.        ]]
#
# -----------------------------
# Época:  52
#
# Conjunto de dados embaralhado:
#  [[-0.19649707 -0.11955184  1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  [-0.10074294 -0.31860073  1.        ]
#  ...
#  [ 0.20300365  0.19595358  1.        ]
#  [ 0.0824192   0.00106606  1.        ]
#  [-0.10038537 -0.60750339  1.        ]]
#
# -----------------------------
# Época:  53
#
# Conjunto de dados embaralhado:
#  [[ 0.80502291 -0.12324873  0.        ]
#  [ 0.19559446 -0.36660313  1.        ]
#  [ 0.31024232 -0.13097232  1.        ]
#  ...
#  [-0.03486406  1.15509737  0.        ]
#  [ 0.30399699  0.00645548  1.        ]
#  [-0.11966564 -0.05239423  1.        ]]
#
# -----------------------------
# Época:  54
#
# Conjunto de dados embaralhado:
#  [[ 0.22245222 -0.2466912   1.        ]
#  [-0.16653566  0.80353489  0.        ]
#  [ 0.07180622  0.49468375  1.        ]
#  ...
#  [ 0.05786483 -0.36451414  1.        ]
#  [ 0.15447827  1.03054581  0.        ]
#  [ 0.17261639 -0.23042727  1.        ]]
#
# -----------------------------
# Época:  55
#
# Conjunto de dados embaralhado:
#  [[-0.07825563 -0.08083512  1.        ]
#  [ 0.01004054 -0.29692638  1.        ]
#  [ 0.00394505  0.1408983   1.        ]
#  ...
#  [-0.21442938  0.00797897  1.        ]
#  [ 0.34015635  0.06961302  1.        ]
#  [ 0.2367801   0.37531654  1.        ]]
#
# -----------------------------
# Época:  56
#
# Conjunto de dados embaralhado:
#  [[ 0.08690974  0.00654493  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  ...
#  [-0.01465206  0.12680101  1.        ]
#  [-0.01249701  1.13463856  0.        ]
#  [-0.05039096 -0.43980938  1.        ]]
#
# -----------------------------
# Época:  57
#
# Conjunto de dados embaralhado:
#  [[-0.04162565  0.12822745  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.66026778 -0.21191075  1.        ]
#  ...
#  [ 0.46304142  0.09405471  1.        ]
#  [ 0.20300365  0.19595358  1.        ]
#  [ 0.07936731 -0.18897409  1.        ]]
#
# -----------------------------
# Época:  58
#
# Conjunto de dados embaralhado:
#  [[ 0.04253339  0.4469942   1.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [-0.26331619  1.10614004  0.        ]
#  ...
#  [ 0.04253339  0.4469942   1.        ]
#  [ 0.66026778 -0.21191075  1.        ]
#  [ 0.40965325  1.15994907  0.        ]]
#
# -----------------------------
# Época:  59
#
# Conjunto de dados embaralhado:
#  [[-0.07722405  0.18953338  1.        ]
#  [-0.06856801  0.16646269  1.        ]
#  [ 0.10170691 -0.02426339  1.        ]
#  ...
#  [-0.03197237  0.16450966  1.        ]
#  [ 0.07028775  0.39056305  1.        ]
#  [ 0.01272533  0.20346543  1.        ]]
#
# -----------------------------
# Época:  60
#
# Conjunto de dados embaralhado:
#  [[-0.19087107  1.1429872   0.        ]
#  [ 0.15640596  0.84981368  0.        ]
#  [-0.46833414 -0.10620722  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.08179828 -0.09956027  1.        ]
#  [-0.22671361  0.21841371  1.        ]]
#
# -----------------------------
# Época:  61
#
# Conjunto de dados embaralhado:
#  [[ 0.26394155  0.32750883  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.19031887  0.13251078  1.        ]
#  ...
#  [ 0.08298076  0.12868493  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [ 0.20300365  0.19595358  1.        ]]
#
# -----------------------------
# Época:  62
#
# Conjunto de dados embaralhado:
#  [[ 0.16775772  0.22831062  1.        ]
#  [ 0.08690974  0.00654493  1.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  ...
#  [ 0.2123362   0.02517371  1.        ]
#  [ 1.18222635 -0.30020136  0.        ]
#  [-0.03486406  1.15509737  0.        ]]
#
# -----------------------------
# Época:  63
#
# Conjunto de dados embaralhado:
#  [[-0.06865786 -0.18994482  1.        ]
#  [ 0.06285892 -0.224167    1.        ]
#  [-0.359685    1.29861984  0.        ]
#  ...
#  [-0.08041492 -0.18693755  1.        ]
#  [ 0.00394505  0.1408983   1.        ]
#  [-0.05640173  0.06447469  1.        ]]
#
# -----------------------------
# Época:  64
#
# Conjunto de dados embaralhado:
#  [[ 0.07028775  0.39056305  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [ 0.27238274  0.18359397  1.        ]
#  ...
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.66026778 -0.21191075  1.        ]
#  [ 0.15207387 -0.1526586   1.        ]]
#
# -----------------------------
# Época:  65
#
# Conjunto de dados embaralhado:
#  [[ 0.34015635  0.06961302  1.        ]
#  [-0.31310084  0.27736732  1.        ]
#  [ 0.07180622  0.49468375  1.        ]
#  ...
#  [-0.10038537 -0.60750339  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.00866547  0.79757433  0.        ]]
#
# -----------------------------
# Época:  66
#
# Conjunto de dados embaralhado:
#  [[ 0.21675147  0.54097717  1.        ]
#  [-0.33711565  0.94927484  0.        ]
#  [ 0.12020386  0.40989806  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.19087107  1.1429872   0.        ]
#  [-0.29123621  0.11011622  1.        ]]
#
# -----------------------------
# Época:  67
#
# Conjunto de dados embaralhado:
#  [[-0.1882854   0.85202358  0.        ]
#  [-0.28620777  1.059365    0.        ]
#  [ 0.01327531  1.10693866  0.        ]
#  ...
#  [-0.05213949 -0.05768201  1.        ]
#  [ 0.22245222 -0.2466912   1.        ]
#  [-0.21442938  0.00797897  1.        ]]
#
# -----------------------------
# Época:  68
#
# Conjunto de dados embaralhado:
#  [[ 0.40713655  1.3881116   0.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  [ 0.07028775  0.39056305  1.        ]
#  ...
#  [-0.25504586  0.25995271  1.        ]
#  [ 0.27835023 -0.27168854  1.        ]
#  [-0.46833414 -0.10620722  1.        ]]
#
# -----------------------------
# Época:  69
#
# Conjunto de dados embaralhado:
#  [[ 0.01047289 -0.025923    1.        ]
#  [-0.0054924  -0.30231266  1.        ]
#  [ 0.27663912  1.28227901  0.        ]
#  ...
#  [ 0.08179828 -0.09956027  1.        ]
#  [ 0.06285892 -0.224167    1.        ]
#  [ 0.2123362   0.02517371  1.        ]]
#
# -----------------------------
# Época:  70
#
# Conjunto de dados embaralhado:
#  [[ 2.80661720e-01  1.30313610e-01  1.00000000e+00]
#  [ 2.78350231e-01 -2.71688543e-01  1.00000000e+00]
#  [ 6.53524158e-04  9.61388153e-01  0.00000000e+00]
#  ...
#  [-2.26153366e-01  1.49350904e-01  1.00000000e+00]
#  [ 3.57510844e-01 -3.08832583e-01  1.00000000e+00]
#  [-2.26153366e-01  1.49350904e-01  1.00000000e+00]]
#
# -----------------------------
# Época:  71
#
# Conjunto de dados embaralhado:
#  [[ 0.35751084 -0.30883258  1.        ]
#  [ 0.32622018 -0.00707064  1.        ]
#  [-0.01465206  0.12680101  1.        ]
#  ...
#  [ 0.31024232 -0.13097232  1.        ]
#  [-0.027351   -0.14271275  1.        ]
#  [-0.03486406  1.15509737  0.        ]]
#
# -----------------------------
# Época:  72
#
# Conjunto de dados embaralhado:
#  [[-0.06832331  1.1562397   0.        ]
#  [-0.2502875   0.13876078  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  ...
#  [ 0.06627455 -0.26057051  1.        ]
#  [-0.16653566  0.80353489  0.        ]
#  [ 0.02913203  0.02879716  1.        ]]
#
# -----------------------------
# Época:  73
#
# Conjunto de dados embaralhado:
#  [[ 0.07988839  0.21101297  1.        ]
#  [ 0.1889197   0.90694034  0.        ]
#  [-0.01249701  1.13463856  0.        ]
#  ...
#  [-0.07825563 -0.08083512  1.        ]
#  [-0.17369552 -0.02572443  1.        ]
#  [-0.03883705  0.13043894  1.        ]]
#
# -----------------------------
# Época:  74
#
# Conjunto de dados embaralhado:
#  [[-0.19908835  0.12926358  1.        ]
#  [ 0.40646314 -0.16905173  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  ...
#  [ 0.02192615  0.7814289   0.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  [-0.03134909  1.34302578  0.        ]]
#
# -----------------------------
# Época:  75
#
# Conjunto de dados embaralhado:
#  [[ 0.15338027  1.0060764   0.        ]
#  [-0.11163154  0.00851976  1.        ]
#  [ 0.20013586 -0.41657686  1.        ]
#  ...
#  [-0.03197237  0.16450966  1.        ]
#  [-0.26924602  0.32950513  1.        ]
#  [ 0.0114998  -0.05939114  1.        ]]
#
# -----------------------------
# Época:  76
# Conjunto de dados embaralhado:
#  [[ 0.15252857  0.01744889  1.        ]
#  [ 0.14814828  1.19025708  0.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [-0.33512655  1.1774808   0.        ]
#  [-0.01545201  0.94861297  0.        ]
#  [ 0.02913203  0.02879716  1.        ]]
#
# -----------------------------
# Época:  77
#
# Conjunto de dados embaralhado:
#  [[-0.01465206  0.12680101  1.        ]
#  [-0.00480107  1.08784779  0.        ]
#  [ 0.02409823  0.16569508  1.        ]
#  ...
#  [-0.32030378 -0.05453506  1.        ]
#  [ 0.0474884   0.76108048  0.        ]
#  [-0.11163154  0.00851976  1.        ]]
#
# -----------------------------
# Época:  78
#
# Conjunto de dados embaralhado:
#  [[ 1.19127938 -0.30479213  0.        ]
#  [-0.29580217  0.56265815  0.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  ...
#  [ 0.06627455 -0.26057051  1.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  [ 0.46304142  0.09405471  1.        ]]
#
# -----------------------------
# Época:  79
#
# Conjunto de dados embaralhado:
#  [[-0.29322959 -0.09065359  1.        ]
#  [ 0.14139125  1.19105258  0.        ]
#  [-0.01545201  0.94861297  0.        ]
#  ...
#  [-0.38616416  0.00437877  1.        ]
#  [-0.19217896  1.04049856  0.        ]
#  [ 0.1196882   0.08875686  1.        ]]
#
# -----------------------------
# Época:  80
#
# Conjunto de dados embaralhado:
#  [[-0.0294872   0.13216526  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [-0.0907412  -0.05805187  1.        ]
#  ...
#  [ 0.06285892 -0.224167    1.        ]
#  [ 0.03645874 -0.23372151  1.        ]
#  [ 0.00394505  0.1408983   1.        ]]
#
# -----------------------------
# Época:  81
#
# Conjunto de dados embaralhado:
#  [[ 0.19110701  0.2105866   1.        ]
#  [ 0.26482475  0.03523472  1.        ]
#  [-0.14967201 -0.19512452  1.        ]
#  ...
#  [ 0.32606995  0.33196305  1.        ]
#  [ 0.05373571  0.5705199   0.        ]
#  [ 0.15252857  0.01744889  1.        ]]
#
# -----------------------------
# Época:  82
#
# Conjunto de dados embaralhado:
#  [[ 0.10233626  0.55422473  0.        ]
#  [-0.00940128 -0.10654841  1.        ]
#  [ 0.06285892 -0.224167    1.        ]
#  ...
#  [ 0.35751084 -0.30883258  1.        ]
#  [ 0.00866547  0.79757433  0.        ]
#  [-0.19908835  0.12926358  1.        ]]
#
# -----------------------------
# Época:  83
#
# Conjunto de dados embaralhado:
#  [[ 0.01327531  1.10693866  0.        ]
#  [ 0.08690974  0.00654493  1.        ]
#  [ 0.31024232 -0.13097232  1.        ]
#  ...
#  [-0.07825563 -0.08083512  1.        ]
#  [ 0.08097161  0.30854443  1.        ]
#  [ 0.29560862  0.08406349  1.        ]]
#
# -----------------------------
# Época:  84
#
# Conjunto de dados embaralhado:
#  [[ 0.01035887  0.19358383  1.        ]
#  [ 0.25776183  0.03455125  1.        ]
#  [ 0.01272533  0.20346543  1.        ]
#  ...
#  [ 0.00866547  0.79757433  0.        ]
#  [ 0.0114998  -0.05939114  1.        ]
#  [ 0.55418408 -0.40033314  0.        ]]
#
# -----------------------------
# Época:  85
#
# Conjunto de dados embaralhado:
#  [[-0.11168935  0.10246164  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.03486406  1.15509737  0.        ]
#  ...
#  [-0.07722405  0.18953338  1.        ]
#  [ 0.14347628  0.25927685  1.        ]
#  [ 0.29230086  1.36100048  0.        ]]
#
# -----------------------------
# Época:  86
#
# Conjunto de dados embaralhado:
#  [[ 0.22245222 -0.2466912   1.        ]
#  [-0.06865786 -0.18994482  1.        ]
#  [-0.17369552 -0.02572443  1.        ]
#  ...
#  [-0.29356844  0.00599321  1.        ]
#  [-0.37025595 -0.19697218  1.        ]
#  [-0.19908835  0.12926358  1.        ]]
#
# -----------------------------
# Época:  87
#
# Conjunto de dados embaralhado:
#  [[-1.24970115e-02  1.13463856e+00  0.00000000e+00]
#  [ 3.41672883e-02  1.71693379e-01  1.00000000e+00]
#  [-3.00171103e-01  3.27243736e-01  1.00000000e+00]
#  ...
#  [-1.39012360e-01  1.07240867e+00  0.00000000e+00]
#  [ 8.24192013e-02  1.06606167e-03  1.00000000e+00]
#  [ 1.08809966e+00  4.15268908e-01  0.00000000e+00]]
#
# -----------------------------
# Época:  88
#
# Conjunto de dados embaralhado:
#  [[-0.3001711   0.32724374  1.        ]
#  [ 0.46304142  0.09405471  1.        ]
#  [ 0.08298076  0.12868493  1.        ]
#  ...
#  [ 0.19559446 -0.36660313  1.        ]
#  [-0.22615337  0.1493509   1.        ]
#  [-0.18777062  0.42687831  1.        ]]
#
# -----------------------------
# Época:  89
#
# Conjunto de dados embaralhado:
#  [[ 0.87781731 -0.03804174  0.        ]
#  [-0.0118221   1.2946323   0.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  ...
#  [ 0.30687156  0.11512797  1.        ]
#  [ 0.36754371  0.0090821   1.        ]
#  [ 0.1460631   0.1776204   1.        ]]
#
# -----------------------------
# Época:  90
#
# Conjunto de dados embaralhado:
#  [[-0.24300515  0.15164356  1.        ]
#  [-0.33512655  1.1774808   0.        ]
#  [ 0.16775772  0.22831062  1.        ]
#  ...
#  [-0.14967201 -0.19512452  1.        ]
#  [ 0.1196882   0.08875686  1.        ]
#  [ 0.2367801   0.37531654  1.        ]]
#
# -----------------------------
# Época:  91
#
# Conjunto de dados embaralhado:
#  [[-0.03883705  0.13043894  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.04253339  0.4469942   1.        ]
#  ...
#  [ 0.25843371 -0.12301855  1.        ]
#  [ 0.87781731 -0.03804174  0.        ]
#  [-0.04175321  0.60137536  0.        ]]
#
# -----------------------------
# Época:  92
#
# Conjunto de dados embaralhado:
#  [[-0.13901236  1.07240867  0.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [ 0.05824952 -0.07760549  1.        ]
#  ...
#  [ 0.29560862  0.08406349  1.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  [-0.07825563 -0.08083512  1.        ]]
#
# -----------------------------
# Época:  93
#
# Conjunto de dados embaralhado:
#  [[ 0.08298076  0.12868493  1.        ]
#  [-0.07617946  0.02320954  1.        ]
#  [ 0.11737716  0.99037835  0.        ]
#  ...
#  [ 0.08097161  0.30854443  1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  [-0.00940128 -0.10654841  1.        ]]
#
# -----------------------------
# Época:  94
#
# Conjunto de dados embaralhado:
#  [[-0.21442938  0.00797897  1.        ]
#  [-0.11163154  0.00851976  1.        ]
#  [ 0.15640596  0.84981368  0.        ]
#  ...
#  [-0.33512655  1.1774808   0.        ]
#  [-0.20009509  0.37511566  1.        ]
#  [ 0.55358262  1.12372063  0.        ]]
#
# -----------------------------
# Época:  95
#
# Conjunto de dados embaralhado:
#  [[ 0.28066172  0.13031361  1.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  [ 0.01272533  0.20346543  1.        ]
#  ...
#  [-0.25518628  0.85789816  0.        ]
#  [ 0.25843371 -0.12301855  1.        ]
#  [ 0.03645874 -0.23372151  1.        ]]
#
# -----------------------------
# Época:  96
#
# Conjunto de dados embaralhado:
#  [[ 0.46304142  0.09405471  1.        ]
#  [ 0.06627455 -0.26057051  1.        ]
#  [ 0.31024232 -0.13097232  1.        ]
#  ...
#  [ 0.35371839  0.80858185  0.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.06282733 -0.32877261  1.        ]]
#
# -----------------------------
# Época:  97
#
# Conjunto de dados embaralhado:
#  [[ 0.07988839  0.21101297  1.        ]
#  [-0.07617946  0.02320954  1.        ]
#  [-0.22615337  0.1493509   1.        ]
#  ...
#  [ 0.32622018 -0.00707064  1.        ]
#  [-0.02215321  0.00269713  1.        ]
#  [ 0.21675147  0.54097717  1.        ]]
#
# -----------------------------
# Época:  98
#
# Conjunto de dados embaralhado:
#  [[ 0.01272533  0.20346543  1.        ]
#  [ 0.30687156  0.11512797  1.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  ...
#  [ 0.08948218 -0.22242627  1.        ]
#  [-0.11163154  0.00851976  1.        ]
#  [-0.06865786 -0.18994482  1.        ]]
#
# -----------------------------
# Época:  99
#
# Conjunto de dados embaralhado:
#  [[ 0.06627455 -0.26057051  1.        ]
#  [-0.03883705  0.13043894  1.        ]
#  [ 0.02192615  0.7814289   0.        ]
#  ...
#  [ 0.1889197   0.90694034  0.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  [ 0.92515819 -0.34720039  0.        ]]
#
# -----------------------------
# Época:  100
#
# Total de épocas:  100
# Total de ajustes feitos nos pesos:  1004

# %%
n.mostra_grafico()

# %%
def previsao():
    real = []
    previsto = []
    numero_de_acertos = 0
    numero_de_erros   = 0
    for i in n.x_teste:
        entrada = np.concatenate((np.array([n.vies]), i[:2]))
        
        yd = int(i[2:])
        yr = round(entrada.dot(n.pesos),4)
        yr = n.funcao_ativacao(yr)
        
        if(yr == yd):
            numero_de_acertos+=1
        else:
            numero_de_erros+=1
        
        real.append(yd)
        previsto.append(yr)
        
    acc = numero_de_acertos/ (numero_de_acertos+numero_de_erros)
    return numero_de_acertos, numero_de_erros, real, previsto, acc

# %%
numero_de_acertos, numero_de_erros, real, previsto, acc = previsao()

# %%
print("Quantidade de acertos: ", numero_de_acertos, "\nQuantidade de erros  : " ,numero_de_erros)
# Out:
# Quantidade de acertos:  230
# Quantidade de erros  :  10

# %% [markdown]
# # Matriz de confusão

# %%
results = {'real': real, 'previsto': previsto}
results_df = pd.DataFrame.from_dict(results)
confusion_matrix = pd.crosstab(results_df['real'], results_df['previsto'], rownames=['Real'], colnames=['Previsto'])
sn.heatmap(confusion_matrix, annot=True, fmt="d")
plt.show()

# %% [markdown]
# # Acurácia

# %%
print("A acurácia é:", acc)
# Out:
# A acurácia é: 0.9583333333333334

# %%
 confusion_matrix.values
# Out:
# array([[163,   3],
#        [  7,  67]], dtype=int64)

# %%
tn = confusion_matrix.values[0][0]
fp = confusion_matrix.values[0][1]
fn = confusion_matrix.values[1][0]
tp = confusion_matrix.values[1][1]
tn, fp, fn, tp
# Out:
# (163, 3, 7, 67)

# %% [markdown]
# # Precisão

# %%
precision = tp/(tp+fp)
print("A precisao e:", precision)
# Out:
# A precisao e: 0.9571428571428572

# %% [markdown]
# # Revocação

# %%
recall = tp/(tp+fn)
print("A revocacao e:", recall)
# Out:
# A revocacao e: 0.9054054054054054

# %% [markdown]
# # F-Score

# %%
f_score = (2*(precision*recall))/(precision+recall)
print("O valor de F-Score e:", f_score)
# Out:
# O valor de F-Score e: 0.9305555555555555

# %% [markdown]
# # Qualidade da Solução
#
# A acurácia do modelo treinado perante o conjunto de testes é de 95,83%, onde de 240 exemplos de teste, apenas 10 tiveram uma saída incorreta. A precisão foi de 0.95, a revocação de 0.90, enquanto o F-Score (média harmônica entre precisão e revocação) foi de 0.93. A partir desses resultados podemos dizer que o modelo (nessas condições, levando em consideração esses pesos, a taxa de aprendizagem e o valor de ϑ) é satisfatório, com uma alta acurácia e o F-Score está próximo de 1, já que o modelo apresentou apenas 7 falsos positivos e 3 falsos negativos.

# %% [markdown]
# # Solução do Perceptron com gráficos usando dados de treinamento e de teste

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(4)
fig.set_figwidth(16)

fig.suptitle("Solução do Perceptron")
ax1.set_title("Treinamento")
ax2.set_title("Teste")

ponto1 = [0,n.x1]
ponto2 = [n.x2,0]
x_values = [ponto1[0], ponto2[0]]
y_values = [ponto1[1], ponto2[1]]

#Treino
for i in n.x_treino:
    x = i[0]
    y = i[1]
    yd = int(i[2])
    if(yd >= 1):
        ax1.scatter(x,y, color='r', s=8)
    else:
        ax1.scatter(x,y, color='b', s=8)

#Teste
for i in n.x_teste:
    x = i[0]
    y = i[1]
    yd = int(i[2])
    if(yd >= 1):
        ax2.scatter(x,y, color='r', s=8)
    else:
        ax2.scatter(x,y, color='b', s=8)

ax1.plot(x_values, y_values)
ax2.plot(x_values, y_values)
